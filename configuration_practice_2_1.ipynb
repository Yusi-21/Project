# %% [markdown]
# <a href="https://colab.research.google.com/github/Yusi-21/Project/blob/main/configuration_practice_2_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (3.7.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.4.7)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (24.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (3.1.4)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)

# %%
pip show matplotlib
# Out:
# Name: matplotlib
# Version: 3.7.1
# Summary: Python plotting package
# Home-page: https://matplotlib.org
# Author: John D. Hunter, Michael Droettboom
# Author-email: matplotlib-users@python.org
# License: PSF
# Location: /usr/local/lib/python3.10/dist-packages
# Requires: contourpy, cycler, fonttools, kiwisolver, numpy, packaging, pillow, pyparsing, python-dateutil
# Required-by: arviz, bigframes, datascience, fastai, geemap, imgaug, matplotlib-venn, missingno, mlxtend, music21, plotnine, prophet, pycocotools, seaborn, wordcloud, yellowbrick

# %%
import matplotlib

print(matplotlib.__version__)
print()
print(matplotlib.__file__)
print()
print(matplotlib.__doc__)
# Out:
# 3.7.1
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/__init__.py
#
#
# An object-oriented plotting library.
#
# A procedural interface is provided by the companion pyplot module,
# which may be imported directly, e.g.::
#
#     import matplotlib.pyplot as plt
#
# or using ipython::
#
#     ipython
#
# at your terminal, followed by::
#
#     In [1]: %matplotlib
#     In [2]: import matplotlib.pyplot as plt
#
# at the ipython shell prompt.
#
# For the most part, direct use of the explicit object-oriented library is
# encouraged when programming; the implicit pyplot interface is primarily for
# working interactively. The exceptions to this suggestion are the pyplot
# functions `.pyplot.figure`, `.pyplot.subplot`, `.pyplot.subplots`, and
# `.pyplot.savefig`, which can greatly simplify scripting.  See
# :ref:`api_interfaces` for an explanation of the tradeoffs between the implicit
# and explicit interfaces.
#
# Modules include:
#
#     :mod:`matplotlib.axes`
#         The `~.axes.Axes` class.  Most pyplot functions are wrappers for
#         `~.axes.Axes` methods.  The axes module is the highest level of OO
#         access to the library.
#
#     :mod:`matplotlib.figure`
#         The `.Figure` class.
#
#     :mod:`matplotlib.artist`
#         The `.Artist` base class for all classes that draw things.
#
#     :mod:`matplotlib.lines`
#         The `.Line2D` class for drawing lines and markers.
#
#     :mod:`matplotlib.patches`
#         Classes for drawing polygons.
#
#     :mod:`matplotlib.text`
#         The `.Text` and `.Annotation` classes.
#
#     :mod:`matplotlib.image`
#         The `.AxesImage` and `.FigureImage` classes.
#
#     :mod:`matplotlib.collections`
#         Classes for efficient drawing of groups of lines or polygons.
#
#     :mod:`matplotlib.colors`
#         Color specifications and making colormaps.
#
#     :mod:`matplotlib.cm`
#         Colormaps, and the `.ScalarMappable` mixin class for providing color
#         mapping functionality to other classes.
#
#     :mod:`matplotlib.ticker`
#         Calculation of tick mark locations and formatting of tick labels.
#
#     :mod:`matplotlib.backends`
#         A subpackage with modules for various GUI libraries and output formats.
#
# The base matplotlib namespace includes:
#
#     `~matplotlib.rcParams`
#         Default configuration settings; their defaults may be overridden using
#         a :file:`matplotlibrc` file.
#
#     `~matplotlib.use`
#         Setting the Matplotlib backend.  This should be called before any
#         figure is created, because it is not possible to switch between
#         different GUI backends after that.
#
# The following environment variables can be used to customize the behavior::
#
#     .. envvar:: MPLBACKEND
#
#       This optional variable can be set to choose the Matplotlib backend. See
#       :ref:`what-is-a-backend`.
#
#     .. envvar:: MPLCONFIGDIR
#
#       This is the directory used to store user customizations to
#       Matplotlib, as well as some caches to improve performance. If
#       :envvar:`MPLCONFIGDIR` is not defined, :file:`{HOME}/.config/matplotlib`
#       and :file:`{HOME}/.cache/matplotlib` are used on Linux, and
#       :file:`{HOME}/.matplotlib` on other platforms, if they are
#       writable. Otherwise, the Python standard library's `tempfile.gettempdir`
#       is used to find a base directory in which the :file:`matplotlib`
#       subdirectory is created.
#
# Matplotlib was initially written by John D. Hunter (1968-2012) and is now
# developed and maintained by a host of others.
#
# Occasionally the internal documentation (python docstrings) will refer
# to MATLAB®, a registered trademark of The MathWorks, Inc.

# %%
# 1. Импорт и вывод информации о пакете matplotlib
import matplotlib

# Версия пакета
print("Версия matplotlib:", matplotlib.__version__)

# Служебная информация
print("Служебная информация о пакете matplotlib:")
print(matplotlib.__doc__)

# 2. Клонируем репозиторий matplotlib
# !git clone https://github.com/matplotlib/matplotlib.git

# 3. Устанавливаем matplotlib из клонированного репозитория
# %cd matplotlib
# !pip install .
# Out:
# Версия matplotlib: 3.7.1
# Служебная информация о пакете matplotlib:
#
# An object-oriented plotting library.
#
# A procedural interface is provided by the companion pyplot module,
# which may be imported directly, e.g.::
#
#     import matplotlib.pyplot as plt
#
# or using ipython::
#
#     ipython
#
# at your terminal, followed by::
#
#     In [1]: %matplotlib
#     In [2]: import matplotlib.pyplot as plt
#
# at the ipython shell prompt.
#
# For the most part, direct use of the explicit object-oriented library is
# encouraged when programming; the implicit pyplot interface is primarily for
# working interactively. The exceptions to this suggestion are the pyplot
# functions `.pyplot.figure`, `.pyplot.subplot`, `.pyplot.subplots`, and
# `.pyplot.savefig`, which can greatly simplify scripting.  See
# :ref:`api_interfaces` for an explanation of the tradeoffs between the implicit
# and explicit interfaces.
#
# Modules include:
#
#     :mod:`matplotlib.axes`
#         The `~.axes.Axes` class.  Most pyplot functions are wrappers for
#         `~.axes.Axes` methods.  The axes module is the highest level of OO
#         access to the library.
#
#     :mod:`matplotlib.figure`
#         The `.Figure` class.
#
#     :mod:`matplotlib.artist`
#         The `.Artist` base class for all classes that draw things.
#
#     :mod:`matplotlib.lines`
#         The `.Line2D` class for drawing lines and markers.
#
#     :mod:`matplotlib.patches`
#         Classes for drawing polygons.
#
#     :mod:`matplotlib.text`
#         The `.Text` and `.Annotation` classes.
#
#     :mod:`matplotlib.image`
#         The `.AxesImage` and `.FigureImage` classes.
#
#     :mod:`matplotlib.collections`
#         Classes for efficient drawing of groups of lines or polygons.
#
#     :mod:`matplotlib.colors`
#         Color specifications and making colormaps.
#
#     :mod:`matplotlib.cm`
#         Colormaps, and the `.ScalarMappable` mixin class for providing color
#         mapping functionality to other classes.
#
#     :mod:`matplotlib.ticker`
#         Calculation of tick mark locations and formatting of tick labels.
#
#     :mod:`matplotlib.backends`
#         A subpackage with modules for various GUI libraries and output formats.
#
# The base matplotlib namespace includes:
#
#     `~matplotlib.rcParams`
#         Default configuration settings; their defaults may be overridden using
#         a :file:`matplotlibrc` file.
#
#     `~matplotlib.use`
#         Setting the Matplotlib backend.  This should be called before any
#         figure is created, because it is not possible to switch between
#         different GUI backends after that.
#
# The following environment variables can be used to customize the behavior::
#
#     .. envvar:: MPLBACKEND
#
#       This optional variable can be set to choose the Matplotlib backend. See
#       :ref:`what-is-a-backend`.
#
#     .. envvar:: MPLCONFIGDIR
#
#       This is the directory used to store user customizations to
#       Matplotlib, as well as some caches to improve performance. If
#       :envvar:`MPLCONFIGDIR` is not defined, :file:`{HOME}/.config/matplotlib`
#       and :file:`{HOME}/.cache/matplotlib` are used on Linux, and
#       :file:`{HOME}/.matplotlib` on other platforms, if they are
#       writable. Otherwise, the Python standard library's `tempfile.gettempdir`
#       is used to find a base directory in which the :file:`matplotlib`
#       subdirectory is created.
#
# Matplotlib was initially written by John D. Hunter (1968-2012) and is now
# developed and maintained by a host of others.
#
# Occasionally the internal documentation (python docstrings) will refer
# to MATLAB®, a registered trademark of The MathWorks, Inc.
#
#
# Cloning into 'matplotlib'...
# remote: Enumerating objects: 330379, done.
# remote: Counting objects: 100% (57/57), done.
# remote: Compressing objects: 100% (45/45), done.
# remote: Total 330379 (delta 20), reused 36 (delta 12), pack-reused 330322 (from 1)
# Receiving objects: 100% (330379/330379), 444.25 MiB | 24.54 MiB/s, done.
# Resolving deltas: 100% (229335/229335), done.
# /content/matplotlib
# Processing /content/matplotlib
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib==3.10.0.dev737+g0988fdaeca) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib==3.10.0.dev737+g0988fdaeca) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib==3.10.0.dev737+g0988fdaeca) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib==3.10.0.dev737+g0988fdaeca) (1.4.7)
# Requirement already satisfied: numpy>=1.23 in /usr/local/lib/python3.10/dist-packages (from matplotlib==3.10.0.dev737+g0988fdaeca) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib==3.10.0.dev737+g0988fdaeca) (24.1)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.10/dist-packages (from matplotlib==3.10.0.dev737+g0988fdaeca) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib==3.10.0.dev737+g0988fdaeca) (3.1.4)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib==3.10.0.dev737+g0988fdaeca) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib==3.10.0.dev737+g0988fdaeca) (1.16.0)
# Building wheels for collected packages: matplotlib
#   Building wheel for matplotlib (pyproject.toml) ... done
#   Created wheel for matplotlib: filename=matplotlib-3.10.0.dev737+g0988fdaeca-cp310-cp310-linux_x86_64.whl size=8393645 sha256=31adc139b4e0dd8119821b05e5fa9f2b9765915b5465d0ad89ffe1f3d70af460
#   Stored in directory: /tmp/pip-ephem-wheel-cache-axetvmbj/wheels/e3/c6/ba/12604b5e54fb221042954e8cd7c062e550f8bfa87810175fd7
# Successfully built matplotlib
# Installing collected packages: matplotlib
#   Attempting uninstall: matplotlib
#     Found existing installation: matplotlib 3.7.1
#     Uninstalling matplotlib-3.7.1:
#       Successfully uninstalled matplotlib-3.7.1
# Successfully installed matplotlib-3.10.0.dev737+g0988fdaeca

# %%
pip install pipdeptree
# Out:
# Collecting pipdeptree
#   Downloading pipdeptree-2.23.4-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: packaging>=24.1 in /usr/local/lib/python3.10/dist-packages (from pipdeptree) (24.1)
# Collecting pip>=24.2 (from pipdeptree)
#   Using cached pip-24.2-py3-none-any.whl.metadata (3.6 kB)
# Downloading pipdeptree-2.23.4-py3-none-any.whl (32 kB)
# Using cached pip-24.2-py3-none-any.whl (1.8 MB)
# Installing collected packages: pip, pipdeptree
#   Attempting uninstall: pip
#     Found existing installation: pip 24.1.2
#     Uninstalling pip-24.1.2:
#       Successfully uninstalled pip-24.1.2
# Successfully installed pip-24.2 pipdeptree-2.23.4

# %%
import pipdeptree

# !pipdeptree
# Out:
# Выходные данные были обрезаны до нескольких последних строк (5000).
# │           │           │   ├── tinycss2 [required: Any, installed: 1.3.0]
# │           │           │   │   └── webencodings [required: >=0.4, installed: 0.5.1]
# │           │           │   └── traitlets [required: >=5.0, installed: 5.7.1]
# │           │           ├── nbformat [required: >=5.2.0, installed: 5.10.4]
# │           │           │   ├── fastjsonschema [required: >=2.15, installed: 2.20.0]
# │           │           │   ├── jsonschema [required: >=2.6, installed: 4.23.0]
# │           │           │   │   ├── attrs [required: >=22.2.0, installed: 24.2.0]
# │           │           │   │   ├── jsonschema-specifications [required: >=2023.03.6, installed: 2023.12.1]
# │           │           │   │   │   └── referencing [required: >=0.31.0, installed: 0.35.1]
# │           │           │   │   │       ├── attrs [required: >=22.2.0, installed: 24.2.0]
# │           │           │   │   │       └── rpds-py [required: >=0.7.0, installed: 0.20.0]
# │           │           │   │   ├── referencing [required: >=0.28.4, installed: 0.35.1]
# │           │           │   │   │   ├── attrs [required: >=22.2.0, installed: 24.2.0]
# │           │           │   │   │   └── rpds-py [required: >=0.7.0, installed: 0.20.0]
# │           │           │   │   └── rpds-py [required: >=0.7.1, installed: 0.20.0]
# │           │           │   ├── jupyter_core [required: >=4.12,!=5.0.*, installed: 5.7.2]
# │           │           │   │   ├── platformdirs [required: >=2.5, installed: 4.3.6]
# │           │           │   │   └── traitlets [required: >=5.3, installed: 5.7.1]
# │           │           │   └── traitlets [required: >=5.1, installed: 5.7.1]
# │           │           ├── packaging [required: Any, installed: 24.1]
# │           │           ├── prometheus_client [required: Any, installed: 0.20.0]
# │           │           ├── pyzmq [required: >=17, installed: 24.0.1]
# │           │           ├── Send2Trash [required: Any, installed: 1.8.3]
# │           │           ├── terminado [required: >=0.8.3, installed: 0.18.1]
# │           │           │   ├── ptyprocess [required: Any, installed: 0.7.0]
# │           │           │   └── tornado [required: >=6.1.0, installed: 6.3.3]
# │           │           ├── tornado [required: >=6.1.0, installed: 6.3.3]
# │           │           ├── traitlets [required: >=5.1, installed: 5.7.1]
# │           │           └── websocket-client [required: Any, installed: 1.8.0]
# │           ├── nbconvert [required: >=5, installed: 6.5.4]
# │           │   ├── beautifulsoup4 [required: Any, installed: 4.12.3]
# │           │   │   └── soupsieve [required: >1.2, installed: 2.6]
# │           │   ├── bleach [required: Any, installed: 6.1.0]
# │           │   │   ├── six [required: >=1.9.0, installed: 1.16.0]
# │           │   │   └── webencodings [required: Any, installed: 0.5.1]
# │           │   ├── defusedxml [required: Any, installed: 0.7.1]
# │           │   ├── entrypoints [required: >=0.2.2, installed: 0.4]
# │           │   ├── Jinja2 [required: >=3.0, installed: 3.1.4]
# │           │   │   └── MarkupSafe [required: >=2.0, installed: 2.1.5]
# │           │   ├── jupyter_core [required: >=4.7, installed: 5.7.2]
# │           │   │   ├── platformdirs [required: >=2.5, installed: 4.3.6]
# │           │   │   └── traitlets [required: >=5.3, installed: 5.7.1]
# │           │   ├── jupyterlab_pygments [required: Any, installed: 0.3.0]
# │           │   ├── lxml [required: Any, installed: 4.9.4]
# │           │   ├── MarkupSafe [required: >=2.0, installed: 2.1.5]
# │           │   ├── mistune [required: >=0.8.1,<2, installed: 0.8.4]
# │           │   ├── nbclient [required: >=0.5.0, installed: 0.10.0]
# │           │   │   ├── jupyter-client [required: >=6.1.12, installed: 6.1.12]
# │           │   │   │   ├── jupyter_core [required: >=4.6.0, installed: 5.7.2]
# │           │   │   │   │   ├── platformdirs [required: >=2.5, installed: 4.3.6]
# │           │   │   │   │   └── traitlets [required: >=5.3, installed: 5.7.1]
# │           │   │   │   ├── python-dateutil [required: >=2.1, installed: 2.8.2]
# │           │   │   │   │   └── six [required: >=1.5, installed: 1.16.0]
# │           │   │   │   ├── pyzmq [required: >=13, installed: 24.0.1]
# │           │   │   │   ├── tornado [required: >=4.1, installed: 6.3.3]
# │           │   │   │   └── traitlets [required: Any, installed: 5.7.1]
# │           │   │   ├── jupyter_core [required: >=4.12,!=5.0.*, installed: 5.7.2]
# │           │   │   │   ├── platformdirs [required: >=2.5, installed: 4.3.6]
# │           │   │   │   └── traitlets [required: >=5.3, installed: 5.7.1]
# │           │   │   ├── nbformat [required: >=5.1, installed: 5.10.4]
# │           │   │   │   ├── fastjsonschema [required: >=2.15, installed: 2.20.0]
# │           │   │   │   ├── jsonschema [required: >=2.6, installed: 4.23.0]
# │           │   │   │   │   ├── attrs [required: >=22.2.0, installed: 24.2.0]
# │           │   │   │   │   ├── jsonschema-specifications [required: >=2023.03.6, installed: 2023.12.1]
# │           │   │   │   │   │   └── referencing [required: >=0.31.0, installed: 0.35.1]
# │           │   │   │   │   │       ├── attrs [required: >=22.2.0, installed: 24.2.0]
# │           │   │   │   │   │       └── rpds-py [required: >=0.7.0, installed: 0.20.0]
# │           │   │   │   │   ├── referencing [required: >=0.28.4, installed: 0.35.1]
# │           │   │   │   │   │   ├── attrs [required: >=22.2.0, installed: 24.2.0]
# │           │   │   │   │   │   └── rpds-py [required: >=0.7.0, installed: 0.20.0]
# │           │   │   │   │   └── rpds-py [required: >=0.7.1, installed: 0.20.0]
# │           │   │   │   ├── jupyter_core [required: >=4.12,!=5.0.*, installed: 5.7.2]
# │           │   │   │   │   ├── platformdirs [required: >=2.5, installed: 4.3.6]
# │           │   │   │   │   └── traitlets [required: >=5.3, installed: 5.7.1]
# │           │   │   │   └── traitlets [required: >=5.1, installed: 5.7.1]
# │           │   │   └── traitlets [required: >=5.4, installed: 5.7.1]
# │           │   ├── nbformat [required: >=5.1, installed: 5.10.4]
# │           │   │   ├── fastjsonschema [required: >=2.15, installed: 2.20.0]
# │           │   │   ├── jsonschema [required: >=2.6, installed: 4.23.0]
# │           │   │   │   ├── attrs [required: >=22.2.0, installed: 24.2.0]
# │           │   │   │   ├── jsonschema-specifications [required: >=2023.03.6, installed: 2023.12.1]
# │           │   │   │   │   └── referencing [required: >=0.31.0, installed: 0.35.1]
# │           │   │   │   │       ├── attrs [required: >=22.2.0, installed: 24.2.0]
# │           │   │   │   │       └── rpds-py [required: >=0.7.0, installed: 0.20.0]
# │           │   │   │   ├── referencing [required: >=0.28.4, installed: 0.35.1]
# │           │   │   │   │   ├── attrs [required: >=22.2.0, installed: 24.2.0]
# │           │   │   │   │   └── rpds-py [required: >=0.7.0, installed: 0.20.0]
# │           │   │   │   └── rpds-py [required: >=0.7.1, installed: 0.20.0]
# │           │   │   ├── jupyter_core [required: >=4.12,!=5.0.*, installed: 5.7.2]
# │           │   │   │   ├── platformdirs [required: >=2.5, installed: 4.3.6]
# │           │   │   │   └── traitlets [required: >=5.3, installed: 5.7.1]
# │           │   │   └── traitlets [required: >=5.1, installed: 5.7.1]
# │           │   ├── packaging [required: Any, installed: 24.1]
# │           │   ├── pandocfilters [required: >=1.4.1, installed: 1.5.1]
# │           │   ├── Pygments [required: >=2.4.1, installed: 2.18.0]
# │           │   ├── tinycss2 [required: Any, installed: 1.3.0]
# │           │   │   └── webencodings [required: >=0.4, installed: 0.5.1]
# │           │   └── traitlets [required: >=5.0, installed: 5.7.1]
# │           ├── nbformat [required: Any, installed: 5.10.4]
# │           │   ├── fastjsonschema [required: >=2.15, installed: 2.20.0]
# │           │   ├── jsonschema [required: >=2.6, installed: 4.23.0]
# │           │   │   ├── attrs [required: >=22.2.0, installed: 24.2.0]
# │           │   │   ├── jsonschema-specifications [required: >=2023.03.6, installed: 2023.12.1]
# │           │   │   │   └── referencing [required: >=0.31.0, installed: 0.35.1]
# │           │   │   │       ├── attrs [required: >=22.2.0, installed: 24.2.0]
# │           │   │   │       └── rpds-py [required: >=0.7.0, installed: 0.20.0]
# │           │   │   ├── referencing [required: >=0.28.4, installed: 0.35.1]
# │           │   │   │   ├── attrs [required: >=22.2.0, installed: 24.2.0]
# │           │   │   │   └── rpds-py [required: >=0.7.0, installed: 0.20.0]
# │           │   │   └── rpds-py [required: >=0.7.1, installed: 0.20.0]
# │           │   ├── jupyter_core [required: >=4.12,!=5.0.*, installed: 5.7.2]
# │           │   │   ├── platformdirs [required: >=2.5, installed: 4.3.6]
# │           │   │   └── traitlets [required: >=5.3, installed: 5.7.1]
# │           │   └── traitlets [required: >=5.1, installed: 5.7.1]
# │           ├── nest-asyncio [required: >=1.5, installed: 1.6.0]
# │           ├── prometheus_client [required: Any, installed: 0.20.0]
# │           ├── pyzmq [required: >=17,<25, installed: 24.0.1]
# │           ├── Send2Trash [required: >=1.8.0, installed: 1.8.3]
# │           ├── terminado [required: >=0.8.3, installed: 0.18.1]
# │           │   ├── ptyprocess [required: Any, installed: 0.7.0]
# │           │   └── tornado [required: >=6.1.0, installed: 6.3.3]
# │           ├── tornado [required: >=6.1, installed: 6.3.3]
# │           └── traitlets [required: >=4.2.1, installed: 5.7.1]
# ├── numpy [required: >=1.9.2, installed: 1.26.4]
# ├── pandas [required: >=0.19.2, installed: 2.1.4]
# │   ├── numpy [required: >=1.22.4,<2, installed: 1.26.4]
# │   ├── python-dateutil [required: >=2.8.2, installed: 2.8.2]
# │   │   └── six [required: >=1.5, installed: 1.16.0]
# │   ├── pytz [required: >=2020.1, installed: 2024.2]
# │   └── tzdata [required: >=2022.1, installed: 2024.1]
# ├── plotly [required: >=4.1.1, installed: 5.15.0]
# │   ├── packaging [required: Any, installed: 24.1]
# │   └── tenacity [required: >=6.2.0, installed: 9.0.0]
# ├── setuptools [required: >=34.4.1, installed: 71.0.4]
# └── six [required: >=1.9.0, installed: 1.16.0]
# cvxopt==1.3.2
# cvxpy==1.5.3
# ├── clarabel [required: >=0.5.0, installed: 0.9.0]
# │   ├── numpy [required: Any, installed: 1.26.4]
# │   └── scipy [required: Any, installed: 1.13.1]
# │       └── numpy [required: >=1.22.4,<2.3, installed: 1.26.4]
# ├── ecos [required: >=2, installed: 2.0.14]
# │   ├── numpy [required: >=1.6, installed: 1.26.4]
# │   └── scipy [required: >=0.9, installed: 1.13.1]
# │       └── numpy [required: >=1.22.4,<2.3, installed: 1.26.4]
# ├── numpy [required: >=1.15, installed: 1.26.4]
# ├── osqp [required: >=0.6.2, installed: 0.6.7.post0]
# │   ├── numpy [required: >=1.7, installed: 1.26.4]
# │   ├── qdldl [required: Any, installed: 0.1.7.post4]
# │   │   ├── numpy [required: >=1.7, installed: 1.26.4]
# │   │   └── scipy [required: >=0.13.2, installed: 1.13.1]
# │   │       └── numpy [required: >=1.22.4,<2.3, installed: 1.26.4]
# │   └── scipy [required: >=0.13.2,!=1.12.0, installed: 1.13.1]
# │       └── numpy [required: >=1.22.4,<2.3, installed: 1.26.4]
# ├── scipy [required: >=1.1.0, installed: 1.13.1]
# │   └── numpy [required: >=1.22.4,<2.3, installed: 1.26.4]
# └── scs [required: >=3.2.4.post1, installed: 3.2.7]
#     ├── numpy [required: Any, installed: 1.26.4]
#     └── scipy [required: Any, installed: 1.13.1]
#         └── numpy [required: >=1.22.4,<2.3, installed: 1.26.4]
# datascience==0.17.6
# ├── branca [required: Any, installed: 0.7.2]
# │   └── Jinja2 [required: >=3, installed: 3.1.4]
# │       └── MarkupSafe [required: >=2.0, installed: 2.1.5]
# ├── folium [required: >=0.9.1, installed: 0.17.0]
# │   ├── branca [required: >=0.6.0, installed: 0.7.2]
# │   │   └── Jinja2 [required: >=3, installed: 3.1.4]
# │   │       └── MarkupSafe [required: >=2.0, installed: 2.1.5]
# │   ├── Jinja2 [required: >=2.9, installed: 3.1.4]
# │   │   └── MarkupSafe [required: >=2.0, installed: 2.1.5]
# │   ├── numpy [required: Any, installed: 1.26.4]
# │   ├── requests [required: Any, installed: 2.32.3]
# │   │   ├── certifi [required: >=2017.4.17, installed: 2024.8.30]
# │   │   ├── charset-normalizer [required: >=2,<4, installed: 3.3.2]
# │   │   ├── idna [required: >=2.5,<4, installed: 3.10]
# │   │   └── urllib3 [required: >=1.21.1,<3, installed: 2.0.7]
# │   └── xyzservices [required: Any, installed: 2024.9.0]
# ├── ipython [required: Any, installed: 7.34.0]
# │   ├── backcall [required: Any, installed: 0.2.0]
# │   ├── decorator [required: Any, installed: 4.4.2]
# │   ├── jedi [required: >=0.16, installed: ?]
# │   ├── matplotlib-inline [required: Any, installed: 0.1.7]
# │   │   └── traitlets [required: Any, installed: 5.7.1]
# │   ├── pexpect [required: >4.3, installed: 4.9.0]
# │   │   └── ptyprocess [required: >=0.5, installed: 0.7.0]
# │   ├── pickleshare [required: Any, installed: 0.7.5]
# │   ├── prompt_toolkit [required: >=2.0.0,<3.1.0,!=3.0.1,!=3.0.0, installed: 3.0.47]
# │   │   └── wcwidth [required: Any, installed: 0.2.13]
# │   ├── Pygments [required: Any, installed: 2.18.0]
# │   ├── setuptools [required: >=18.5, installed: 71.0.4]
# │   └── traitlets [required: >=4.2, installed: 5.7.1]
# ├── matplotlib [required: >=3.0.0, installed: 3.10.0.dev737+g0988fdaeca]
# │   ├── contourpy [required: >=1.0.1, installed: 1.3.0]
# │   │   └── numpy [required: >=1.23, installed: 1.26.4]
# │   ├── cycler [required: >=0.10, installed: 0.12.1]
# │   ├── fonttools [required: >=4.22.0, installed: 4.53.1]
# │   ├── kiwisolver [required: >=1.3.1, installed: 1.4.7]
# │   ├── numpy [required: >=1.23, installed: 1.26.4]
# │   ├── packaging [required: >=20.0, installed: 24.1]
# │   ├── pillow [required: >=8, installed: 10.4.0]
# │   ├── pyparsing [required: >=2.3.1, installed: 3.1.4]
# │   └── python-dateutil [required: >=2.7, installed: 2.8.2]
# │       └── six [required: >=1.5, installed: 1.16.0]
# ├── numpy [required: Any, installed: 1.26.4]
# ├── pandas [required: Any, installed: 2.1.4]
# │   ├── numpy [required: >=1.22.4,<2, installed: 1.26.4]
# │   ├── python-dateutil [required: >=2.8.2, installed: 2.8.2]
# │   │   └── six [required: >=1.5, installed: 1.16.0]
# │   ├── pytz [required: >=2020.1, installed: 2024.2]
# │   └── tzdata [required: >=2022.1, installed: 2024.1]
# ├── plotly [required: Any, installed: 5.15.0]
# │   ├── packaging [required: Any, installed: 24.1]
# │   └── tenacity [required: >=6.2.0, installed: 9.0.0]
# ├── scipy [required: Any, installed: 1.13.1]
# │   └── numpy [required: >=1.22.4,<2.3, installed: 1.26.4]
# └── setuptools [required: Any, installed: 71.0.4]
# dbus-python==1.2.18
# debugpy==1.6.6
# distributed==2024.8.0
# ├── click [required: >=8.0, installed: 8.1.7]
# ├── cloudpickle [required: >=1.5.0, installed: 2.2.1]
# ├── dask [required: ==2024.8.0, installed: 2024.8.0]
# │   ├── click [required: >=8.1, installed: 8.1.7]
# │   ├── cloudpickle [required: >=1.5.0, installed: 2.2.1]
# │   ├── fsspec [required: >=2021.09.0, installed: 2024.6.1]
# │   ├── importlib_metadata [required: >=4.13.0, installed: 8.5.0]
# │   │   └── zipp [required: >=3.20, installed: 3.20.2]
# │   ├── packaging [required: >=20.0, installed: 24.1]
# │   ├── partd [required: >=1.4.0, installed: 1.4.2]
# │   │   ├── locket [required: Any, installed: 1.0.0]
# │   │   └── toolz [required: Any, installed: 0.12.1]
# │   ├── PyYAML [required: >=5.3.1, installed: 6.0.2]
# │   └── toolz [required: >=0.10.0, installed: 0.12.1]
# ├── Jinja2 [required: >=2.10.3, installed: 3.1.4]
# │   └── MarkupSafe [required: >=2.0, installed: 2.1.5]
# ├── locket [required: >=1.0.0, installed: 1.0.0]
# ├── msgpack [required: >=1.0.0, installed: 1.0.8]
# ├── packaging [required: >=20.0, installed: 24.1]
# ├── psutil [required: >=5.7.2, installed: 5.9.5]
# ├── PyYAML [required: >=5.3.1, installed: 6.0.2]
# ├── sortedcontainers [required: >=2.0.5, installed: 2.4.0]
# ├── tblib [required: >=1.6.0, installed: 3.0.0]
# ├── toolz [required: >=0.10.0, installed: 0.12.1]
# ├── tornado [required: >=6.0.4, installed: 6.3.3]
# ├── urllib3 [required: >=1.24.3, installed: 2.0.7]
# └── zict [required: >=3.0.0, installed: 3.0.0]
# distro==1.7.0
# dlib==19.24.2
# dopamine_rl==4.0.9
# ├── absl-py [required: >=0.9.0, installed: 1.4.0]
# ├── flax [required: >=0.2.0, installed: 0.8.4]
# │   ├── jax [required: >=0.4.19, installed: 0.4.26]
# │   │   ├── ml-dtypes [required: >=0.2.0, installed: 0.4.1]
# │   │   │   ├── numpy [required: >1.20, installed: 1.26.4]
# │   │   │   └── numpy [required: >=1.21.2, installed: 1.26.4]
# │   │   ├── numpy [required: >=1.22, installed: 1.26.4]
# │   │   ├── opt-einsum [required: Any, installed: 3.3.0]
# │   │   │   └── numpy [required: >=1.7, installed: 1.26.4]
# │   │   └── scipy [required: >=1.9, installed: 1.13.1]
# │   │       └── numpy [required: >=1.22.4,<2.3, installed: 1.26.4]
# │   ├── msgpack [required: Any, installed: 1.0.8]
# │   ├── numpy [required: >=1.22, installed: 1.26.4]
# │   ├── optax [required: Any, installed: 0.2.2]
# │   │   ├── absl-py [required: >=0.7.1, installed: 1.4.0]
# │   │   ├── chex [required: >=0.1.86, installed: 0.1.86]
# │   │   │   ├── absl-py [required: >=0.9.0, installed: 1.4.0]
# │   │   │   ├── jax [required: >=0.4.16, installed: 0.4.26]
# │   │   │   │   ├── ml-dtypes [required: >=0.2.0, installed: 0.4.1]
# │   │   │   │   │   ├── numpy [required: >1.20, installed: 1.26.4]
# │   │   │   │   │   └── numpy [required: >=1.21.2, installed: 1.26.4]
# │   │   │   │   ├── numpy [required: >=1.22, installed: 1.26.4]
# │   │   │   │   ├── opt-einsum [required: Any, installed: 3.3.0]
# │   │   │   │   │   └── numpy [required: >=1.7, installed: 1.26.4]
# │   │   │   │   └── scipy [required: >=1.9, installed: 1.13.1]
# │   │   │   │       └── numpy [required: >=1.22.4,<2.3, installed: 1.26.4]
# │   │   │   ├── jaxlib [required: >=0.1.37, installed: 0.4.26+cuda12.cudnn89]
# │   │   │   │   ├── ml-dtypes [required: >=0.2.0, installed: 0.4.1]
# │   │   │   │   │   ├── numpy [required: >1.20, installed: 1.26.4]
# │   │   │   │   │   └── numpy [required: >=1.21.2, installed: 1.26.4]
# │   │   │   │   ├── numpy [required: >=1.22, installed: 1.26.4]
# │   │   │   │   └── scipy [required: >=1.9, installed: 1.13.1]
# │   │   │   │       └── numpy [required: >=1.22.4,<2.3, installed: 1.26.4]
# │   │   │   ├── numpy [required: >=1.24.1, installed: 1.26.4]
# │   │   │   ├── toolz [required: >=0.9.0, installed: 0.12.1]
# │   │   │   └── typing_extensions [required: >=4.2.0, installed: 4.12.2]
# │   │   ├── jax [required: >=0.1.55, installed: 0.4.26]
# │   │   │   ├── ml-dtypes [required: >=0.2.0, installed: 0.4.1]
# │   │   │   │   ├── numpy [required: >1.20, installed: 1.26.4]
# │   │   │   │   └── numpy [required: >=1.21.2, installed: 1.26.4]
# │   │   │   ├── numpy [required: >=1.22, installed: 1.26.4]
# │   │   │   ├── opt-einsum [required: Any, installed: 3.3.0]
# │   │   │   │   └── numpy [required: >=1.7, installed: 1.26.4]
# │   │   │   └── scipy [required: >=1.9, installed: 1.13.1]
# │   │   │       └── numpy [required: >=1.22.4,<2.3, installed: 1.26.4]
# │   │   ├── jaxlib [required: >=0.1.37, installed: 0.4.26+cuda12.cudnn89]
# │   │   │   ├── ml-dtypes [required: >=0.2.0, installed: 0.4.1]
# │   │   │   │   ├── numpy [required: >1.20, installed: 1.26.4]
# │   │   │   │   └── numpy [required: >=1.21.2, installed: 1.26.4]
# │   │   │   ├── numpy [required: >=1.22, installed: 1.26.4]
# │   │   │   └── scipy [required: >=1.9, installed: 1.13.1]
# │   │   │       └── numpy [required: >=1.22.4,<2.3, installed: 1.26.4]
# │   │   └── numpy [required: >=1.18.0, installed: 1.26.4]
# │   ├── orbax-checkpoint [required: Any, installed: 0.6.4]
# │   │   ├── absl-py [required: Any, installed: 1.4.0]
# │   │   ├── etils [required: Any, installed: 1.9.4]
# │   │   ├── humanize [required: Any, installed: 4.10.0]
# │   │   ├── jax [required: >=0.4.26, installed: 0.4.26]
# │   │   │   ├── ml-dtypes [required: >=0.2.0, installed: 0.4.1]
# │   │   │   │   ├── numpy [required: >1.20, installed: 1.26.4]
# │   │   │   │   └── numpy [required: >=1.21.2, installed: 1.26.4]
# │   │   │   ├── numpy [required: >=1.22, installed: 1.26.4]
# │   │   │   ├── opt-einsum [required: Any, installed: 3.3.0]
# │   │   │   │   └── numpy [required: >=1.7, installed: 1.26.4]
# │   │   │   └── scipy [required: >=1.9, installed: 1.13.1]
# │   │   │       └── numpy [required: >=1.22.4,<2.3, installed: 1.26.4]
# │   │   ├── jaxlib [required: Any, installed: 0.4.26+cuda12.cudnn89]
# │   │   │   ├── ml-dtypes [required: >=0.2.0, installed: 0.4.1]
# │   │   │   │   ├── numpy [required: >1.20, installed: 1.26.4]
# │   │   │   │   └── numpy [required: >=1.21.2, installed: 1.26.4]
# │   │   │   ├── numpy [required: >=1.22, installed: 1.26.4]
# │   │   │   └── scipy [required: >=1.9, installed: 1.13.1]
# │   │   │       └── numpy [required: >=1.22.4,<2.3, installed: 1.26.4]
# │   │   ├── msgpack [required: Any, installed: 1.0.8]
# │   │   ├── nest-asyncio [required: Any, installed: 1.6.0]
# │   │   ├── numpy [required: Any, installed: 1.26.4]
# │   │   ├── protobuf [required: Any, installed: 3.20.3]
# │   │   ├── PyYAML [required: Any, installed: 6.0.2]
# │   │   ├── tensorstore [required: >=0.1.60, installed: 0.1.65]
# │   │   │   ├── ml-dtypes [required: >=0.3.1, installed: 0.4.1]
# │   │   │   │   ├── numpy [required: >1.20, installed: 1.26.4]
# │   │   │   │   └── numpy [required: >=1.21.2, installed: 1.26.4]
# │   │   │   └── numpy [required: >=1.22.0, installed: 1.26.4]
# │   │   └── typing_extensions [required: Any, installed: 4.12.2]
# │   ├── PyYAML [required: >=5.4.1, installed: 6.0.2]
# │   ├── rich [required: >=11.1, installed: 13.8.1]
# │   │   ├── markdown-it-py [required: >=2.2.0, installed: 3.0.0]
# │   │   │   └── mdurl [required: ~=0.1, installed: 0.1.2]
# │   │   └── Pygments [required: >=2.13.0,<3.0.0, installed: 2.18.0]
# │   ├── tensorstore [required: Any, installed: 0.1.65]
# │   │   ├── ml-dtypes [required: >=0.3.1, installed: 0.4.1]
# │   │   │   ├── numpy [required: >1.20, installed: 1.26.4]
# │   │   │   └── numpy [required: >=1.21.2, installed: 1.26.4]
# │   │   └── numpy [required: >=1.22.0, installed: 1.26.4]
# │   └── typing_extensions [required: >=4.2, installed: 4.12.2]
# ├── gin-config [required: >=0.3.0, installed: 0.5.0]
# ├── gym [required: <=0.25.2, installed: 0.25.2]
# │   ├── cloudpickle [required: >=1.2.0, installed: 2.2.1]
# │   ├── gym-notices [required: >=0.0.4, installed: 0.0.8]
# │   └── numpy [required: >=1.18.0, installed: 1.26.4]
# ├── jax [required: >=0.1.72, installed: 0.4.26]
# │   ├── ml-dtypes [required: >=0.2.0, installed: 0.4.1]
# │   │   ├── numpy [required: >1.20, installed: 1.26.4]
# │   │   └── numpy [required: >=1.21.2, installed: 1.26.4]
# │   ├── numpy [required: >=1.22, installed: 1.26.4]
# │   ├── opt-einsum [required: Any, installed: 3.3.0]
# │   │   └── numpy [required: >=1.7, installed: 1.26.4]
# │   └── scipy [required: >=1.9, installed: 1.13.1]
# │       └── numpy [required: >=1.22.4,<2.3, installed: 1.26.4]
# ├── jaxlib [required: >=0.1.51, installed: 0.4.26+cuda12.cudnn89]
# │   ├── ml-dtypes [required: >=0.2.0, installed: 0.4.1]
# │   │   ├── numpy [required: >1.20, installed: 1.26.4]
# │   │   └── numpy [required: >=1.21.2, installed: 1.26.4]
# │   ├── numpy [required: >=1.22, installed: 1.26.4]
# │   └── scipy [required: >=1.9, installed: 1.13.1]
# │       └── numpy [required: >=1.22.4,<2.3, installed: 1.26.4]
# ├── numpy [required: >=1.16.4, installed: 1.26.4]
# ├── opencv-python [required: >=3.4.8.29, installed: 4.10.0.84]
# │   ├── numpy [required: >=1.21.2, installed: 1.26.4]
# │   ├── numpy [required: >=1.17.0, installed: 1.26.4]
# │   ├── numpy [required: >=1.17.3, installed: 1.26.4]
# │   └── numpy [required: >=1.19.3, installed: 1.26.4]
# ├── pandas [required: >=0.24.2, installed: 2.1.4]
# │   ├── numpy [required: >=1.22.4,<2, installed: 1.26.4]
# │   ├── python-dateutil [required: >=2.8.2, installed: 2.8.2]
# │   │   └── six [required: >=1.5, installed: 1.16.0]
# │   ├── pytz [required: >=2020.1, installed: 2024.2]
# │   └── tzdata [required: >=2022.1, installed: 2024.1]
# ├── pillow [required: >=7.0.0, installed: 10.4.0]
# ├── pygame [required: >=1.9.2, installed: 2.6.0]
# ├── tensorflow [required: >=2.2.0, installed: 2.17.0]
# │   ├── absl-py [required: >=1.0.0, installed: 1.4.0]
# │   ├── astunparse [required: >=1.6.0, installed: 1.6.3]
# │   │   ├── six [required: >=1.6.1,<2.0, installed: 1.16.0]
# │   │   └── wheel [required: >=0.23.0,<1.0, installed: 0.44.0]
# │   ├── flatbuffers [required: >=24.3.25, installed: 24.3.25]
# │   ├── gast [required: >=0.2.1,!=0.5.2,!=0.5.1,!=0.5.0, installed: 0.6.0]
# │   ├── google-pasta [required: >=0.1.1, installed: 0.2.0]
# │   │   └── six [required: Any, installed: 1.16.0]
# │   ├── grpcio [required: >=1.24.3,<2.0, installed: 1.64.1]
# │   ├── h5py [required: >=3.10.0, installed: 3.11.0]
# │   │   └── numpy [required: >=1.17.3, installed: 1.26.4]
# │   ├── keras [required: >=3.2.0, installed: 3.4.1]
# │   │   ├── absl-py [required: Any, installed: 1.4.0]
# │   │   ├── h5py [required: Any, installed: 3.11.0]
# │   │   │   └── numpy [required: >=1.17.3, installed: 1.26.4]
# │   │   ├── ml-dtypes [required: Any, installed: 0.4.1]
# │   │   │   ├── numpy [required: >1.20, installed: 1.26.4]
# │   │   │   └── numpy [required: >=1.21.2, installed: 1.26.4]
# │   │   ├── namex [required: Any, installed: 0.0.8]
# │   │   ├── numpy [required: Any, installed: 1.26.4]
# │   │   ├── optree [required: Any, installed: 0.12.1]
# │   │   │   └── typing_extensions [required: >=4.5.0, installed: 4.12.2]
# │   │   ├── packaging [required: Any, installed: 24.1]
# │   │   └── rich [required: Any, installed: 13.8.1]
# │   │       ├── markdown-it-py [required: >=2.2.0, installed: 3.0.0]
# │   │       │   └── mdurl [required: ~=0.1, installed: 0.1.2]
# │   │       └── Pygments [required: >=2.13.0,<3.0.0, installed: 2.18.0]
# │   ├── libclang [required: >=13.0.0, installed: 18.1.1]
# │   ├── ml-dtypes [required: >=0.3.1,<0.5.0, installed: 0.4.1]
# │   │   ├── numpy [required: >1.20, installed: 1.26.4]
# │   │   └── numpy [required: >=1.21.2, installed: 1.26.4]
# │   ├── numpy [required: >=1.23.5,<2.0.0, installed: 1.26.4]
# │   ├── opt-einsum [required: >=2.3.2, installed: 3.3.0]
# │   │   └── numpy [required: >=1.7, installed: 1.26.4]
# │   ├── packaging [required: Any, installed: 24.1]
# │   ├── protobuf [required: >=3.20.3,<5.0.0dev,!=4.21.5,!=4.21.4,!=4.21.3,!=4.21.2,!=4.21.1,!=4.21.0, installed: 3.20.3]
# │   ├── requests [required: >=2.21.0,<3, installed: 2.32.3]
# │   │   ├── certifi [required: >=2017.4.17, installed: 2024.8.30]
# │   │   ├── charset-normalizer [required: >=2,<4, installed: 3.3.2]
# │   │   ├── idna [required: >=2.5,<4, installed: 3.10]
# │   │   └── urllib3 [required: >=1.21.1,<3, installed: 2.0.7]
# │   ├── setuptools [required: Any, installed: 71.0.4]
# │   ├── six [required: >=1.12.0, installed: 1.16.0]
# │   ├── tensorboard [required: >=2.17,<2.18, installed: 2.17.0]
# │   │   ├── absl-py [required: >=0.4, installed: 1.4.0]
# │   │   ├── grpcio [required: >=1.48.2, installed: 1.64.1]
# │   │   ├── Markdown [required: >=2.6.8, installed: 3.7]
# │   │   ├── numpy [required: >=1.12.0, installed: 1.26.4]
# │   │   ├── protobuf [required: >=3.19.6,<5.0.0,!=4.24.0, installed: 3.20.3]
# │   │   ├── setuptools [required: >=41.0.0, installed: 71.0.4]
# │   │   ├── six [required: >1.9, installed: 1.16.0]
# │   │   ├── tensorboard-data-server [required: >=0.7.0,<0.8.0, installed: 0.7.2]
# │   │   └── Werkzeug [required: >=1.0.1, installed: 3.0.4]
# │   │       └── MarkupSafe [required: >=2.1.1, installed: 2.1.5]
# │   ├── tensorflow-io-gcs-filesystem [required: >=0.23.1, installed: 0.37.1]
# │   ├── termcolor [required: >=1.1.0, installed: 2.4.0]
# │   ├── typing_extensions [required: >=3.6.6, installed: 4.12.2]
# │   └── wrapt [required: >=1.11.0, installed: 1.16.0]
# ├── tensorflow-probability [required: >=0.13.0, installed: 0.24.0]
# │   ├── absl-py [required: Any, installed: 1.4.0]
# │   ├── cloudpickle [required: >=1.3, installed: 2.2.1]
# │   ├── decorator [required: Any, installed: 4.4.2]
# │   ├── dm-tree [required: Any, installed: 0.1.8]
# │   ├── gast [required: >=0.3.2, installed: 0.6.0]
# │   ├── numpy [required: >=1.13.3, installed: 1.26.4]
# │   └── six [required: >=1.10.0, installed: 1.16.0]
# ├── tf-slim [required: >=1.0, installed: 1.1.0]
# │   └── absl-py [required: >=0.2.2, installed: 1.4.0]
# └── tqdm [required: >=4.64.1, installed: 4.66.5]
# duckdb==1.1.0
# easydict==1.13
# editdistance==0.8.1
# einops==0.8.0
# en-core-web-sm==3.7.1
# └── spacy [required: >=3.7.2,<3.8.0, installed: 3.7.6]
#     ├── catalogue [required: >=2.0.6,<2.1.0, installed: 2.0.10]
#     ├── cymem [required: >=2.0.2,<2.1.0, installed: 2.0.8]
#     ├── Jinja2 [required: Any, installed: 3.1.4]
#     │   └── MarkupSafe [required: >=2.0, installed: 2.1.5]
#     ├── langcodes [required: >=3.2.0,<4.0.0, installed: 3.4.0]
#     │   └── language_data [required: >=1.2, installed: 1.2.0]
#     │       └── marisa-trie [required: >=0.7.7, installed: 1.2.0]
#     │           └── setuptools [required: Any, installed: 71.0.4]
#     ├── murmurhash [required: >=0.28.0,<1.1.0, installed: 1.0.10]
#     ├── numpy [required: >=1.19.0, installed: 1.26.4]
#     ├── packaging [required: >=20.0, installed: 24.1]
#     ├── preshed [required: >=3.0.2,<3.1.0, installed: 3.0.9]
#     │   ├── cymem [required: >=2.0.2,<2.1.0, installed: 2.0.8]
#     │   └── murmurhash [required: >=0.28.0,<1.1.0, installed: 1.0.10]
#     ├── pydantic [required: >=1.7.4,<3.0.0,!=1.8.1,!=1.8, installed: 2.9.2]
#     │   ├── annotated-types [required: >=0.6.0, installed: 0.7.0]
#     │   ├── pydantic_core [required: ==2.23.4, installed: 2.23.4]
#     │   │   └── typing_extensions [required: >=4.6.0,!=4.7.0, installed: 4.12.2]
#     │   └── typing_extensions [required: >=4.6.1, installed: 4.12.2]
#     ├── requests [required: >=2.13.0,<3.0.0, installed: 2.32.3]
#     │   ├── certifi [required: >=2017.4.17, installed: 2024.8.30]
#     │   ├── charset-normalizer [required: >=2,<4, installed: 3.3.2]
#     │   ├── idna [required: >=2.5,<4, installed: 3.10]
#     │   └── urllib3 [required: >=1.21.1,<3, installed: 2.0.7]
#     ├── setuptools [required: Any, installed: 71.0.4]
#     ├── spacy-legacy [required: >=3.0.11,<3.1.0, installed: 3.0.12]
#     ├── spacy-loggers [required: >=1.0.0,<2.0.0, installed: 1.0.5]
#     ├── srsly [required: >=2.4.3,<3.0.0, installed: 2.4.8]
#     │   └── catalogue [required: >=2.0.3,<2.1.0, installed: 2.0.10]
#     ├── thinc [required: >=8.2.2,<8.3.0, installed: 8.2.5]
#     │   ├── blis [required: >=0.7.8,<0.8.0, installed: 0.7.11]
#     │   │   └── numpy [required: >=1.19.0, installed: 1.26.4]
#     │   ├── catalogue [required: >=2.0.4,<2.1.0, installed: 2.0.10]
#     │   ├── confection [required: >=0.0.1,<1.0.0, installed: 0.1.5]
#     │   │   ├── pydantic [required: >=1.7.4,<3.0.0,!=1.8.1,!=1.8, installed: 2.9.2]
#     │   │   │   ├── annotated-types [required: >=0.6.0, installed: 0.7.0]
#     │   │   │   ├── pydantic_core [required: ==2.23.4, installed: 2.23.4]
#     │   │   │   │   └── typing_extensions [required: >=4.6.0,!=4.7.0, installed: 4.12.2]
#     │   │   │   └── typing_extensions [required: >=4.6.1, installed: 4.12.2]
#     │   │   └── srsly [required: >=2.4.0,<3.0.0, installed: 2.4.8]
#     │   │       └── catalogue [required: >=2.0.3,<2.1.0, installed: 2.0.10]
#     │   ├── cymem [required: >=2.0.2,<2.1.0, installed: 2.0.8]
#     │   ├── murmurhash [required: >=1.0.2,<1.1.0, installed: 1.0.10]
#     │   ├── numpy [required: >=1.19.0,<2.0.0, installed: 1.26.4]
#     │   ├── packaging [required: >=20.0, installed: 24.1]
#     │   ├── preshed [required: >=3.0.2,<3.1.0, installed: 3.0.9]
#     │   │   ├── cymem [required: >=2.0.2,<2.1.0, installed: 2.0.8]
#     │   │   └── murmurhash [required: >=0.28.0,<1.1.0, installed: 1.0.10]
#     │   ├── pydantic [required: >=1.7.4,<3.0.0,!=1.8.1,!=1.8, installed: 2.9.2]
#     │   │   ├── annotated-types [required: >=0.6.0, installed: 0.7.0]
#     │   │   ├── pydantic_core [required: ==2.23.4, installed: 2.23.4]
#     │   │   │   └── typing_extensions [required: >=4.6.0,!=4.7.0, installed: 4.12.2]
#     │   │   └── typing_extensions [required: >=4.6.1, installed: 4.12.2]
#     │   ├── setuptools [required: Any, installed: 71.0.4]
#     │   ├── srsly [required: >=2.4.0,<3.0.0, installed: 2.4.8]
#     │   │   └── catalogue [required: >=2.0.3,<2.1.0, installed: 2.0.10]
#     │   └── wasabi [required: >=0.8.1,<1.2.0, installed: 1.1.3]
#     ├── tqdm [required: >=4.38.0,<5.0.0, installed: 4.66.5]
#     ├── typer [required: >=0.3.0,<1.0.0, installed: 0.12.5]
#     │   ├── click [required: >=8.0.0, installed: 8.1.7]
#     │   ├── rich [required: >=10.11.0, installed: 13.8.1]
#     │   │   ├── markdown-it-py [required: >=2.2.0, installed: 3.0.0]
#     │   │   │   └── mdurl [required: ~=0.1, installed: 0.1.2]
#     │   │   └── Pygments [required: >=2.13.0,<3.0.0, installed: 2.18.0]
#     │   ├── shellingham [required: >=1.3.0, installed: 1.5.4]
#     │   └── typing_extensions [required: >=3.7.4.3, installed: 4.12.2]
#     ├── wasabi [required: >=0.9.1,<1.2.0, installed: 1.1.3]
#     └── weasel [required: >=0.1.0,<0.5.0, installed: 0.4.1]
#         ├── cloudpathlib [required: >=0.7.0,<1.0.0, installed: 0.19.0]
#         │   └── typing_extensions [required: >4, installed: 4.12.2]
#         ├── confection [required: >=0.0.4,<0.2.0, installed: 0.1.5]
#         │   ├── pydantic [required: >=1.7.4,<3.0.0,!=1.8.1,!=1.8, installed: 2.9.2]
#         │   │   ├── annotated-types [required: >=0.6.0, installed: 0.7.0]
#         │   │   ├── pydantic_core [required: ==2.23.4, installed: 2.23.4]
#         │   │   │   └── typing_extensions [required: >=4.6.0,!=4.7.0, installed: 4.12.2]
#         │   │   └── typing_extensions [required: >=4.6.1, installed: 4.12.2]
#         │   └── srsly [required: >=2.4.0,<3.0.0, installed: 2.4.8]
#         │       └── catalogue [required: >=2.0.3,<2.1.0, installed: 2.0.10]
#         ├── packaging [required: >=20.0, installed: 24.1]
#         ├── pydantic [required: >=1.7.4,<3.0.0,!=1.8.1,!=1.8, installed: 2.9.2]
#         │   ├── annotated-types [required: >=0.6.0, installed: 0.7.0]
#         │   ├── pydantic_core [required: ==2.23.4, installed: 2.23.4]
#         │   │   └── typing_extensions [required: >=4.6.0,!=4.7.0, installed: 4.12.2]
#         │   └── typing_extensions [required: >=4.6.1, installed: 4.12.2]
#         ├── requests [required: >=2.13.0,<3.0.0, installed: 2.32.3]
#         │   ├── certifi [required: >=2017.4.17, installed: 2024.8.30]
#         │   ├── charset-normalizer [required: >=2,<4, installed: 3.3.2]
#         │   ├── idna [required: >=2.5,<4, installed: 3.10]
#         │   └── urllib3 [required: >=1.21.1,<3, installed: 2.0.7]
#         ├── smart-open [required: >=5.2.1,<8.0.0, installed: 7.0.4]
#         │   └── wrapt [required: Any, installed: 1.16.0]
#         ├── srsly [required: >=2.4.3,<3.0.0, installed: 2.4.8]
#         │   └── catalogue [required: >=2.0.3,<2.1.0, installed: 2.0.10]
#         ├── typer [required: >=0.3.0,<1.0.0, installed: 0.12.5]
#         │   ├── click [required: >=8.0.0, installed: 8.1.7]
#         │   ├── rich [required: >=10.11.0, installed: 13.8.1]
#         │   │   ├── markdown-it-py [required: >=2.2.0, installed: 3.0.0]
#         │   │   │   └── mdurl [required: ~=0.1, installed: 0.1.2]
#         │   │   └── Pygments [required: >=2.13.0,<3.0.0, installed: 2.18.0]
#         │   ├── shellingham [required: >=1.3.0, installed: 1.5.4]
#         │   └── typing_extensions [required: >=3.7.4.3, installed: 4.12.2]
#         └── wasabi [required: >=0.9.1,<1.2.0, installed: 1.1.3]
# fastai==2.7.17
# ├── fastcore [required: >=1.5.29,<1.8, installed: 1.7.8]
# │   └── packaging [required: Any, installed: 24.1]
# ├── fastdownload [required: >=0.0.5,<2, installed: 0.0.7]
# │   ├── fastcore [required: >=1.3.26, installed: 1.7.8]
# │   │   └── packaging [required: Any, installed: 24.1]
# │   └── fastprogress [required: Any, installed: 1.0.3]
# ├── fastprogress [required: >=0.2.4, installed: 1.0.3]
# ├── matplotlib [required: Any, installed: 3.10.0.dev737+g0988fdaeca]
# │   ├── contourpy [required: >=1.0.1, installed: 1.3.0]
# │   │   └── numpy [required: >=1.23, installed: 1.26.4]
# │   ├── cycler [required: >=0.10, installed: 0.12.1]
# │   ├── fonttools [required: >=4.22.0, installed: 4.53.1]
# │   ├── kiwisolver [required: >=1.3.1, installed: 1.4.7]
# │   ├── numpy [required: >=1.23, installed: 1.26.4]
# │   ├── packaging [required: >=20.0, installed: 24.1]
# │   ├── pillow [required: >=8, installed: 10.4.0]
# │   ├── pyparsing [required: >=2.3.1, installed: 3.1.4]
# │   └── python-dateutil [required: >=2.7, installed: 2.8.2]
# │       └── six [required: >=1.5, installed: 1.16.0]
# ├── packaging [required: Any, installed: 24.1]
# ├── pandas [required: Any, installed: 2.1.4]
# │   ├── numpy [required: >=1.22.4,<2, installed: 1.26.4]
# │   ├── python-dateutil [required: >=2.8.2, installed: 2.8.2]
# │   │   └── six [required: >=1.5, installed: 1.16.0]
# │   ├── pytz [required: >=2020.1, installed: 2024.2]
# │   └── tzdata [required: >=2022.1, installed: 2024.1]
# ├── pillow [required: >=9.0.0, installed: 10.4.0]
# ├── pip [required: Any, installed: 24.2]
# ├── PyYAML [required: Any, installed: 6.0.2]
# ├── requests [required: Any, installed: 2.32.3]
# │   ├── certifi [required: >=2017.4.17, installed: 2024.8.30]
# │   ├── charset-normalizer [required: >=2,<4, installed: 3.3.2]
# │   ├── idna [required: >=2.5,<4, installed: 3.10]
# │   └── urllib3 [required: >=1.21.1,<3, installed: 2.0.7]
# ├── scikit-learn [required: Any, installed: 1.3.2]
# │   ├── joblib [required: >=1.1.1, installed: 1.4.2]
# │   ├── numpy [required: >=1.17.3,<2.0, installed: 1.26.4]
# │   ├── scipy [required: >=1.5.0, installed: 1.13.1]
# │   │   └── numpy [required: >=1.22.4,<2.3, installed: 1.26.4]
# │   └── threadpoolctl [required: >=2.0.0, installed: 3.5.0]
# ├── scipy [required: Any, installed: 1.13.1]
# │   └── numpy [required: >=1.22.4,<2.3, installed: 1.26.4]
# ├── spacy [required: <4, installed: 3.7.6]
# │   ├── catalogue [required: >=2.0.6,<2.1.0, installed: 2.0.10]
# │   ├── cymem [required: >=2.0.2,<2.1.0, installed: 2.0.8]
# │   ├── Jinja2 [required: Any, installed: 3.1.4]
# │   │   └── MarkupSafe [required: >=2.0, installed: 2.1.5]
# │   ├── langcodes [required: >=3.2.0,<4.0.0, installed: 3.4.0]
# │   │   └── language_data [required: >=1.2, installed: 1.2.0]
# │   │       └── marisa-trie [required: >=0.7.7, installed: 1.2.0]
# │   │           └── setuptools [required: Any, installed: 71.0.4]
# │   ├── murmurhash [required: >=0.28.0,<1.1.0, installed: 1.0.10]
# │   ├── numpy [required: >=1.19.0, installed: 1.26.4]
# │   ├── packaging [required: >=20.0, installed: 24.1]
# │   ├── preshed [required: >=3.0.2,<3.1.0, installed: 3.0.9]
# │   │   ├── cymem [required: >=2.0.2,<2.1.0, installed: 2.0.8]
# │   │   └── murmurhash [required: >=0.28.0,<1.1.0, installed: 1.0.10]
# │   ├── pydantic [required: >=1.7.4,<3.0.0,!=1.8.1,!=1.8, installed: 2.9.2]
# │   │   ├── annotated-types [required: >=0.6.0, installed: 0.7.0]
# │   │   ├── pydantic_core [required: ==2.23.4, installed: 2.23.4]
# │   │   │   └── typing_extensions [required: >=4.6.0,!=4.7.0, installed: 4.12.2]
# │   │   └── typing_extensions [required: >=4.6.1, installed: 4.12.2]
# │   ├── requests [required: >=2.13.0,<3.0.0, installed: 2.32.3]
# │   │   ├── certifi [required: >=2017.4.17, installed: 2024.8.30]
# │   │   ├── charset-normalizer [required: >=2,<4, installed: 3.3.2]
# │   │   ├── idna [required: >=2.5,<4, installed: 3.10]
# │   │   └── urllib3 [required: >=1.21.1,<3, installed: 2.0.7]
# │   ├── setuptools [required: Any, installed: 71.0.4]
# │   ├── spacy-legacy [required: >=3.0.11,<3.1.0, installed: 3.0.12]
# │   ├── spacy-loggers [required: >=1.0.0,<2.0.0, installed: 1.0.5]
# │   ├── srsly [required: >=2.4.3,<3.0.0, installed: 2.4.8]
# │   │   └── catalogue [required: >=2.0.3,<2.1.0, installed: 2.0.10]
# │   ├── thinc [required: >=8.2.2,<8.3.0, installed: 8.2.5]
# │   │   ├── blis [required: >=0.7.8,<0.8.0, installed: 0.7.11]
# │   │   │   └── numpy [required: >=1.19.0, installed: 1.26.4]
# │   │   ├── catalogue [required: >=2.0.4,<2.1.0, installed: 2.0.10]
# │   │   ├── confection [required: >=0.0.1,<1.0.0, installed: 0.1.5]
# │   │   │   ├── pydantic [required: >=1.7.4,<3.0.0,!=1.8.1,!=1.8, installed: 2.9.2]
# │   │   │   │   ├── annotated-types [required: >=0.6.0, installed: 0.7.0]
# │   │   │   │   ├── pydantic_core [required: ==2.23.4, installed: 2.23.4]
# │   │   │   │   │   └── typing_extensions [required: >=4.6.0,!=4.7.0, installed: 4.12.2]
# │   │   │   │   └── typing_extensions [required: >=4.6.1, installed: 4.12.2]
# │   │   │   └── srsly [required: >=2.4.0,<3.0.0, installed: 2.4.8]
# │   │   │       └── catalogue [required: >=2.0.3,<2.1.0, installed: 2.0.10]
# │   │   ├── cymem [required: >=2.0.2,<2.1.0, installed: 2.0.8]
# │   │   ├── murmurhash [required: >=1.0.2,<1.1.0, installed: 1.0.10]
# │   │   ├── numpy [required: >=1.19.0,<2.0.0, installed: 1.26.4]
# │   │   ├── packaging [required: >=20.0, installed: 24.1]
# │   │   ├── preshed [required: >=3.0.2,<3.1.0, installed: 3.0.9]
# │   │   │   ├── cymem [required: >=2.0.2,<2.1.0, installed: 2.0.8]
# │   │   │   └── murmurhash [required: >=0.28.0,<1.1.0, installed: 1.0.10]
# │   │   ├── pydantic [required: >=1.7.4,<3.0.0,!=1.8.1,!=1.8, installed: 2.9.2]
# │   │   │   ├── annotated-types [required: >=0.6.0, installed: 0.7.0]
# │   │   │   ├── pydantic_core [required: ==2.23.4, installed: 2.23.4]
# │   │   │   │   └── typing_extensions [required: >=4.6.0,!=4.7.0, installed: 4.12.2]
# │   │   │   └── typing_extensions [required: >=4.6.1, installed: 4.12.2]
# │   │   ├── setuptools [required: Any, installed: 71.0.4]
# │   │   ├── srsly [required: >=2.4.0,<3.0.0, installed: 2.4.8]
# │   │   │   └── catalogue [required: >=2.0.3,<2.1.0, installed: 2.0.10]
# │   │   └── wasabi [required: >=0.8.1,<1.2.0, installed: 1.1.3]
# │   ├── tqdm [required: >=4.38.0,<5.0.0, installed: 4.66.5]
# │   ├── typer [required: >=0.3.0,<1.0.0, installed: 0.12.5]
# │   │   ├── click [required: >=8.0.0, installed: 8.1.7]
# │   │   ├── rich [required: >=10.11.0, installed: 13.8.1]
# │   │   │   ├── markdown-it-py [required: >=2.2.0, installed: 3.0.0]
# │   │   │   │   └── mdurl [required: ~=0.1, installed: 0.1.2]
# │   │   │   └── Pygments [required: >=2.13.0,<3.0.0, installed: 2.18.0]
# │   │   ├── shellingham [required: >=1.3.0, installed: 1.5.4]
# │   │   └── typing_extensions [required: >=3.7.4.3, installed: 4.12.2]
# │   ├── wasabi [required: >=0.9.1,<1.2.0, installed: 1.1.3]
# │   └── weasel [required: >=0.1.0,<0.5.0, installed: 0.4.1]
# │       ├── cloudpathlib [required: >=0.7.0,<1.0.0, installed: 0.19.0]
# │       │   └── typing_extensions [required: >4, installed: 4.12.2]
# │       ├── confection [required: >=0.0.4,<0.2.0, installed: 0.1.5]
# │       │   ├── pydantic [required: >=1.7.4,<3.0.0,!=1.8.1,!=1.8, installed: 2.9.2]
# │       │   │   ├── annotated-types [required: >=0.6.0, installed: 0.7.0]
# │       │   │   ├── pydantic_core [required: ==2.23.4, installed: 2.23.4]
# │       │   │   │   └── typing_extensions [required: >=4.6.0,!=4.7.0, installed: 4.12.2]
# │       │   │   └── typing_extensions [required: >=4.6.1, installed: 4.12.2]
# │       │   └── srsly [required: >=2.4.0,<3.0.0, installed: 2.4.8]
# │       │       └── catalogue [required: >=2.0.3,<2.1.0, installed: 2.0.10]
# │       ├── packaging [required: >=20.0, installed: 24.1]
# │       ├── pydantic [required: >=1.7.4,<3.0.0,!=1.8.1,!=1.8, installed: 2.9.2]
# │       │   ├── annotated-types [required: >=0.6.0, installed: 0.7.0]
# │       │   ├── pydantic_core [required: ==2.23.4, installed: 2.23.4]
# │       │   │   └── typing_extensions [required: >=4.6.0,!=4.7.0, installed: 4.12.2]
# │       │   └── typing_extensions [required: >=4.6.1, installed: 4.12.2]
# │       ├── requests [required: >=2.13.0,<3.0.0, installed: 2.32.3]
# │       │   ├── certifi [required: >=2017.4.17, installed: 2024.8.30]
# │       │   ├── charset-normalizer [required: >=2,<4, installed: 3.3.2]
# │       │   ├── idna [required: >=2.5,<4, installed: 3.10]
# │       │   └── urllib3 [required: >=1.21.1,<3, installed: 2.0.7]
# │       ├── smart-open [required: >=5.2.1,<8.0.0, installed: 7.0.4]
# │       │   └── wrapt [required: Any, installed: 1.16.0]
# │       ├── srsly [required: >=2.4.3,<3.0.0, installed: 2.4.8]
# │       │   └── catalogue [required: >=2.0.3,<2.1.0, installed: 2.0.10]
# │       ├── typer [required: >=0.3.0,<1.0.0, installed: 0.12.5]
# │       │   ├── click [required: >=8.0.0, installed: 8.1.7]
# │       │   ├── rich [required: >=10.11.0, installed: 13.8.1]
# │       │   │   ├── markdown-it-py [required: >=2.2.0, installed: 3.0.0]
# │       │   │   │   └── mdurl [required: ~=0.1, installed: 0.1.2]
# │       │   │   └── Pygments [required: >=2.13.0,<3.0.0, installed: 2.18.0]
# │       │   ├── shellingham [required: >=1.3.0, installed: 1.5.4]
# │       │   └── typing_extensions [required: >=3.7.4.3, installed: 4.12.2]
# │       └── wasabi [required: >=0.9.1,<1.2.0, installed: 1.1.3]
# ├── torch [required: >=1.10,<2.5, installed: 2.4.1+cu121]
# │   ├── filelock [required: Any, installed: 3.16.1]
# │   ├── fsspec [required: Any, installed: 2024.6.1]
# │   ├── Jinja2 [required: Any, installed: 3.1.4]
# │   │   └── MarkupSafe [required: >=2.0, installed: 2.1.5]
# │   ├── networkx [required: Any, installed: 3.3]
# │   ├── sympy [required: Any, installed: 1.13.2]
# │   │   └── mpmath [required: >=1.1.0,<1.4, installed: 1.3.0]
# │   └── typing_extensions [required: >=4.8.0, installed: 4.12.2]
# └── torchvision [required: >=0.11, installed: 0.19.1+cu121]
#     ├── numpy [required: Any, installed: 1.26.4]
#     ├── pillow [required: >=5.3.0,!=8.3.*, installed: 10.4.0]
#     └── torch [required: ==2.4.1, installed: 2.4.1+cu121]
#         ├── filelock [required: Any, installed: 3.16.1]
#         ├── fsspec [required: Any, installed: 2024.6.1]
#         ├── Jinja2 [required: Any, installed: 3.1.4]
#         │   └── MarkupSafe [required: >=2.0, installed: 2.1.5]
#         ├── networkx [required: Any, installed: 3.3]
#         ├── sympy [required: Any, installed: 1.13.2]
#         │   └── mpmath [required: >=1.1.0,<1.4, installed: 1.3.0]
#         └── typing_extensions [required: >=4.8.0, installed: 4.12.2]
# firebase-admin==6.5.0
# ├── CacheControl [required: >=0.12.6, installed: 0.14.0]
# │   ├── msgpack [required: >=0.5.2,<2.0.0, installed: 1.0.8]
# │   └── requests [required: >=2.16.0, installed: 2.32.3]
# │       ├── certifi [required: >=2017.4.17, installed: 2024.8.30]
# │       ├── charset-normalizer [required: >=2,<4, installed: 3.3.2]
# │       ├── idna [required: >=2.5,<4, installed: 3.10]
# │       └── urllib3 [required: >=1.21.1,<3, installed: 2.0.7]
# ├── google-api-core [required: >=1.22.1,<3.0.0dev, installed: 2.19.2]
# │   ├── google-auth [required: >=2.14.1,<3.0.dev0, installed: 2.27.0]
# │   │   ├── cachetools [required: >=2.0.0,<6.0, installed: 5.5.0]
# │   │   ├── pyasn1_modules [required: >=0.2.1, installed: 0.4.1]
# │   │   │   └── pyasn1 [required: >=0.4.6,<0.7.0, installed: 0.6.1]
# │   │   └── rsa [required: >=3.1.4,<5, installed: 4.9]
# │   │       └── pyasn1 [required: >=0.1.3, installed: 0.6.1]
# │   ├── googleapis-common-protos [required: >=1.56.2,<2.0.dev0, installed: 1.65.0]
# │   │   └── protobuf [required: >=3.20.2,<6.0.0.dev0,!=4.21.5,!=4.21.4,!=4.21.3,!=4.21.2,!=4.21.1,!=3.20.1,!=3.20.0, installed: 3.20.3]
# │   ├── proto-plus [required: >=1.22.3,<2.0.0dev, installed: 1.24.0]
# │   │   └── protobuf [required: >=3.19.0,<6.0.0dev, installed: 3.20.3]
# │   ├── protobuf [required: >=3.19.5,<6.0.0.dev0,!=4.21.5,!=4.21.4,!=4.21.3,!=4.21.2,!=4.21.1,!=4.21.0,!=3.20.1,!=3.20.0, installed: 3.20.3]
# │   └── requests [required: >=2.18.0,<3.0.0.dev0, installed: 2.32.3]
# │       ├── certifi [required: >=2017.4.17, installed: 2024.8.30]
# │       ├── charset-normalizer [required: >=2,<4, installed: 3.3.2]
# │       ├── idna [required: >=2.5,<4, installed: 3.10]
# │       └── urllib3 [required: >=1.21.1,<3, installed: 2.0.7]
# ├── google-api-python-client [required: >=1.7.8, installed: 2.137.0]
# │   ├── google-api-core [required: >=1.31.5,<3.0.0.dev0,!=2.3.0,!=2.2.*,!=2.1.*,!=2.0.*, installed: 2.19.2]
# │   │   ├── google-auth [required: >=2.14.1,<3.0.dev0, installed: 2.27.0]
# │   │   │   ├── cachetools [required: >=2.0.0,<6.0, installed: 5.5.0]
# │   │   │   ├── pyasn1_modules [required: >=0.2.1, installed: 0.4.1]
# │   │   │   │   └── pyasn1 [required: >=0.4.6,<0.7.0, installed: 0.6.1]
# │   │   │   └── rsa [required: >=3.1.4,<5, installed: 4.9]
# │   │   │       └── pyasn1 [required: >=0.1.3, installed: 0.6.1]
# │   │   ├── googleapis-common-protos [required: >=1.56.2,<2.0.dev0, installed: 1.65.0]
# │   │   │   └── protobuf [required: >=3.20.2,<6.0.0.dev0,!=4.21.5,!=4.21.4,!=4.21.3,!=4.21.2,!=4.21.1,!=3.20.1,!=3.20.0, installed: 3.20.3]
# │   │   ├── proto-plus [required: >=1.22.3,<2.0.0dev, installed: 1.24.0]
# │   │   │   └── protobuf [required: >=3.19.0,<6.0.0dev, installed: 3.20.3]
# ...
# rpy2==3.4.2
# ├── cffi [required: >=1.10.0, installed: 1.17.1]
# │   └── pycparser [required: Any, installed: 2.22]
# ├── Jinja2 [required: Any, installed: 3.1.4]
# │   └── MarkupSafe [required: >=2.0, installed: 2.1.5]
# ├── pytz [required: Any, installed: 2024.2]
# └── tzlocal [required: Any, installed: 5.2]
# SecretStorage==3.3.1
# sentencepiece==0.1.99
# sklearn-pandas==2.2.0
# ├── numpy [required: >=1.18.1, installed: 1.26.4]
# ├── pandas [required: >=1.1.4, installed: 2.1.4]
# │   ├── numpy [required: >=1.22.4,<2, installed: 1.26.4]
# │   ├── python-dateutil [required: >=2.8.2, installed: 2.8.2]
# │   │   └── six [required: >=1.5, installed: 1.16.0]
# │   ├── pytz [required: >=2020.1, installed: 2024.2]
# │   └── tzdata [required: >=2022.1, installed: 2024.1]
# ├── scikit-learn [required: >=0.23.0, installed: 1.3.2]
# │   ├── joblib [required: >=1.1.1, installed: 1.4.2]
# │   ├── numpy [required: >=1.17.3,<2.0, installed: 1.26.4]
# │   ├── scipy [required: >=1.5.0, installed: 1.13.1]
# │   │   └── numpy [required: >=1.22.4,<2.3, installed: 1.26.4]
# │   └── threadpoolctl [required: >=2.0.0, installed: 3.5.0]
# └── scipy [required: >=1.5.1, installed: 1.13.1]
#     └── numpy [required: >=1.22.4,<2.3, installed: 1.26.4]
# Sphinx==5.0.2
# ├── alabaster [required: >=0.7,<0.8, installed: 0.7.16]
# ├── babel [required: >=1.3, installed: 2.16.0]
# ├── docutils [required: >=0.14,<0.19, installed: 0.18.1]
# ├── imagesize [required: Any, installed: 1.4.1]
# ├── Jinja2 [required: >=2.3, installed: 3.1.4]
# │   └── MarkupSafe [required: >=2.0, installed: 2.1.5]
# ├── packaging [required: Any, installed: 24.1]
# ├── Pygments [required: >=2.0, installed: 2.18.0]
# ├── requests [required: >=2.5.0, installed: 2.32.3]
# │   ├── certifi [required: >=2017.4.17, installed: 2024.8.30]
# │   ├── charset-normalizer [required: >=2,<4, installed: 3.3.2]
# │   ├── idna [required: >=2.5,<4, installed: 3.10]
# │   └── urllib3 [required: >=1.21.1,<3, installed: 2.0.7]
# ├── snowballstemmer [required: >=1.1, installed: 2.2.0]
# ├── sphinxcontrib-applehelp [required: Any, installed: 2.0.0]
# ├── sphinxcontrib-devhelp [required: Any, installed: 2.0.0]
# ├── sphinxcontrib-htmlhelp [required: >=2.0.0, installed: 2.1.0]
# ├── sphinxcontrib-jsmath [required: Any, installed: 1.0.1]
# ├── sphinxcontrib-qthelp [required: Any, installed: 2.0.0]
# └── sphinxcontrib-serializinghtml [required: >=1.1.5, installed: 2.0.0]
# tables==3.8.0
# ├── blosc2 [required: ~=2.0.0, installed: 2.0.0]
# │   └── msgpack [required: Any, installed: 1.0.8]
# ├── Cython [required: >=0.29.21, installed: 3.0.11]
# ├── numexpr [required: >=2.6.2, installed: 2.10.1]
# │   └── numpy [required: >=1.23.0, installed: 1.26.4]
# ├── numpy [required: >=1.19.0, installed: 1.26.4]
# ├── packaging [required: Any, installed: 24.1]
# └── py-cpuinfo [required: Any, installed: 9.0.0]
# tensorflow-datasets==4.9.6
# ├── absl-py [required: Any, installed: 1.4.0]
# ├── array_record [required: >=0.5.0, installed: 0.5.1]
# │   ├── absl-py [required: Any, installed: 1.4.0]
# │   └── etils [required: Any, installed: 1.9.4]
# ├── click [required: Any, installed: 8.1.7]
# ├── dm-tree [required: Any, installed: 0.1.8]
# ├── etils [required: >=1.6.0, installed: 1.9.4]
# ├── immutabledict [required: Any, installed: 4.2.0]
# ├── numpy [required: Any, installed: 1.26.4]
# ├── promise [required: Any, installed: 2.3]
# │   └── six [required: Any, installed: 1.16.0]
# ├── protobuf [required: >=3.20, installed: 3.20.3]
# ├── psutil [required: Any, installed: 5.9.5]
# ├── pyarrow [required: Any, installed: 14.0.2]
# │   └── numpy [required: >=1.16.6, installed: 1.26.4]
# ├── requests [required: >=2.19.0, installed: 2.32.3]
# │   ├── certifi [required: >=2017.4.17, installed: 2024.8.30]
# │   ├── charset-normalizer [required: >=2,<4, installed: 3.3.2]
# │   ├── idna [required: >=2.5,<4, installed: 3.10]
# │   └── urllib3 [required: >=1.21.1,<3, installed: 2.0.7]
# ├── simple-parsing [required: Any, installed: 0.1.6]
# │   ├── docstring_parser [required: >=0.15,<1.0, installed: 0.16]
# │   └── typing_extensions [required: >=4.5.0, installed: 4.12.2]
# ├── tensorflow-metadata [required: Any, installed: 1.15.0]
# │   ├── absl-py [required: >=0.9,<3.0.0, installed: 1.4.0]
# │   └── protobuf [required: >=3.20.3,<4.21, installed: 3.20.3]
# ├── termcolor [required: Any, installed: 2.4.0]
# ├── toml [required: Any, installed: 0.10.2]
# ├── tqdm [required: Any, installed: 4.66.5]
# └── wrapt [required: Any, installed: 1.16.0]
# tensorflow-hub==0.16.1
# ├── numpy [required: >=1.12.0, installed: 1.26.4]
# ├── protobuf [required: >=3.19.6, installed: 3.20.3]
# └── tf_keras [required: >=2.14.1, installed: 2.17.0]
#     └── tensorflow [required: >=2.17,<2.18, installed: 2.17.0]
#         ├── absl-py [required: >=1.0.0, installed: 1.4.0]
#         ├── astunparse [required: >=1.6.0, installed: 1.6.3]
#         │   ├── six [required: >=1.6.1,<2.0, installed: 1.16.0]
#         │   └── wheel [required: >=0.23.0,<1.0, installed: 0.44.0]
#         ├── flatbuffers [required: >=24.3.25, installed: 24.3.25]
#         ├── gast [required: >=0.2.1,!=0.5.2,!=0.5.1,!=0.5.0, installed: 0.6.0]
#         ├── google-pasta [required: >=0.1.1, installed: 0.2.0]
#         │   └── six [required: Any, installed: 1.16.0]
#         ├── grpcio [required: >=1.24.3,<2.0, installed: 1.64.1]
#         ├── h5py [required: >=3.10.0, installed: 3.11.0]
#         │   └── numpy [required: >=1.17.3, installed: 1.26.4]
#         ├── keras [required: >=3.2.0, installed: 3.4.1]
#         │   ├── absl-py [required: Any, installed: 1.4.0]
#         │   ├── h5py [required: Any, installed: 3.11.0]
#         │   │   └── numpy [required: >=1.17.3, installed: 1.26.4]
#         │   ├── ml-dtypes [required: Any, installed: 0.4.1]
#         │   │   ├── numpy [required: >1.20, installed: 1.26.4]
#         │   │   └── numpy [required: >=1.21.2, installed: 1.26.4]
#         │   ├── namex [required: Any, installed: 0.0.8]
#         │   ├── numpy [required: Any, installed: 1.26.4]
#         │   ├── optree [required: Any, installed: 0.12.1]
#         │   │   └── typing_extensions [required: >=4.5.0, installed: 4.12.2]
#         │   ├── packaging [required: Any, installed: 24.1]
#         │   └── rich [required: Any, installed: 13.8.1]
#         │       ├── markdown-it-py [required: >=2.2.0, installed: 3.0.0]
#         │       │   └── mdurl [required: ~=0.1, installed: 0.1.2]
#         │       └── Pygments [required: >=2.13.0,<3.0.0, installed: 2.18.0]
#         ├── libclang [required: >=13.0.0, installed: 18.1.1]
#         ├── ml-dtypes [required: >=0.3.1,<0.5.0, installed: 0.4.1]
#         │   ├── numpy [required: >1.20, installed: 1.26.4]
#         │   └── numpy [required: >=1.21.2, installed: 1.26.4]
#         ├── numpy [required: >=1.23.5,<2.0.0, installed: 1.26.4]
#         ├── opt-einsum [required: >=2.3.2, installed: 3.3.0]
#         │   └── numpy [required: >=1.7, installed: 1.26.4]
#         ├── packaging [required: Any, installed: 24.1]
#         ├── protobuf [required: >=3.20.3,<5.0.0dev,!=4.21.5,!=4.21.4,!=4.21.3,!=4.21.2,!=4.21.1,!=4.21.0, installed: 3.20.3]
#         ├── requests [required: >=2.21.0,<3, installed: 2.32.3]
#         │   ├── certifi [required: >=2017.4.17, installed: 2024.8.30]
#         │   ├── charset-normalizer [required: >=2,<4, installed: 3.3.2]
#         │   ├── idna [required: >=2.5,<4, installed: 3.10]
#         │   └── urllib3 [required: >=1.21.1,<3, installed: 2.0.7]
#         ├── setuptools [required: Any, installed: 71.0.4]
#         ├── six [required: >=1.12.0, installed: 1.16.0]
#         ├── tensorboard [required: >=2.17,<2.18, installed: 2.17.0]
#         │   ├── absl-py [required: >=0.4, installed: 1.4.0]
#         │   ├── grpcio [required: >=1.48.2, installed: 1.64.1]
#         │   ├── Markdown [required: >=2.6.8, installed: 3.7]
#         │   ├── numpy [required: >=1.12.0, installed: 1.26.4]
#         │   ├── protobuf [required: >=3.19.6,<5.0.0,!=4.24.0, installed: 3.20.3]
#         │   ├── setuptools [required: >=41.0.0, installed: 71.0.4]
#         │   ├── six [required: >1.9, installed: 1.16.0]
#         │   ├── tensorboard-data-server [required: >=0.7.0,<0.8.0, installed: 0.7.2]
#         │   └── Werkzeug [required: >=1.0.1, installed: 3.0.4]
#         │       └── MarkupSafe [required: >=2.1.1, installed: 2.1.5]
#         ├── tensorflow-io-gcs-filesystem [required: >=0.23.1, installed: 0.37.1]
#         ├── termcolor [required: >=1.1.0, installed: 2.4.0]
#         ├── typing_extensions [required: >=3.6.6, installed: 4.12.2]
#         └── wrapt [required: >=1.11.0, installed: 1.16.0]
# textblob==0.17.1
# └── nltk [required: >=3.1, installed: 3.8.1]
#     ├── click [required: Any, installed: 8.1.7]
#     ├── joblib [required: Any, installed: 1.4.2]
#     ├── regex [required: >=2021.8.3, installed: 2024.9.11]
#     └── tqdm [required: Any, installed: 4.66.5]
# torchaudio==2.4.1+cu121
# └── torch [required: ==2.4.1, installed: 2.4.1+cu121]
#     ├── filelock [required: Any, installed: 3.16.1]
#     ├── fsspec [required: Any, installed: 2024.6.1]
#     ├── Jinja2 [required: Any, installed: 3.1.4]
#     │   └── MarkupSafe [required: >=2.0, installed: 2.1.5]
#     ├── networkx [required: Any, installed: 3.3]
#     ├── sympy [required: Any, installed: 1.13.2]
#     │   └── mpmath [required: >=1.1.0,<1.4, installed: 1.3.0]
#     └── typing_extensions [required: >=4.8.0, installed: 4.12.2]
# torchsummary==1.5.1
# transformers==4.44.2
# ├── filelock [required: Any, installed: 3.16.1]
# ├── huggingface-hub [required: >=0.23.2,<1.0, installed: 0.24.7]
# │   ├── filelock [required: Any, installed: 3.16.1]
# │   ├── fsspec [required: >=2023.5.0, installed: 2024.6.1]
# │   ├── packaging [required: >=20.9, installed: 24.1]
# │   ├── PyYAML [required: >=5.1, installed: 6.0.2]
# │   ├── requests [required: Any, installed: 2.32.3]
# │   │   ├── certifi [required: >=2017.4.17, installed: 2024.8.30]
# │   │   ├── charset-normalizer [required: >=2,<4, installed: 3.3.2]
# │   │   ├── idna [required: >=2.5,<4, installed: 3.10]
# │   │   └── urllib3 [required: >=1.21.1,<3, installed: 2.0.7]
# │   ├── tqdm [required: >=4.42.1, installed: 4.66.5]
# │   └── typing_extensions [required: >=3.7.4.3, installed: 4.12.2]
# ├── numpy [required: >=1.17, installed: 1.26.4]
# ├── packaging [required: >=20.0, installed: 24.1]
# ├── PyYAML [required: >=5.1, installed: 6.0.2]
# ├── regex [required: !=2019.12.17, installed: 2024.9.11]
# ├── requests [required: Any, installed: 2.32.3]
# │   ├── certifi [required: >=2017.4.17, installed: 2024.8.30]
# │   ├── charset-normalizer [required: >=2,<4, installed: 3.3.2]
# │   ├── idna [required: >=2.5,<4, installed: 3.10]
# │   └── urllib3 [required: >=1.21.1,<3, installed: 2.0.7]
# ├── safetensors [required: >=0.4.1, installed: 0.4.5]
# ├── tokenizers [required: >=0.19,<0.20, installed: 0.19.1]
# │   └── huggingface-hub [required: >=0.16.4,<1.0, installed: 0.24.7]
# │       ├── filelock [required: Any, installed: 3.16.1]
# │       ├── fsspec [required: >=2023.5.0, installed: 2024.6.1]
# │       ├── packaging [required: >=20.9, installed: 24.1]
# │       ├── PyYAML [required: >=5.1, installed: 6.0.2]
# │       ├── requests [required: Any, installed: 2.32.3]
# │       │   ├── certifi [required: >=2017.4.17, installed: 2024.8.30]
# │       │   ├── charset-normalizer [required: >=2,<4, installed: 3.3.2]
# │       │   ├── idna [required: >=2.5,<4, installed: 3.10]
# │       │   └── urllib3 [required: >=1.21.1,<3, installed: 2.0.7]
# │       ├── tqdm [required: >=4.42.1, installed: 4.66.5]
# │       └── typing_extensions [required: >=3.7.4.3, installed: 4.12.2]
# └── tqdm [required: >=4.27, installed: 4.66.5]
# tweepy==4.14.0
# ├── oauthlib [required: >=3.2.0,<4, installed: 3.2.2]
# ├── requests [required: >=2.27.0,<3, installed: 2.32.3]
# │   ├── certifi [required: >=2017.4.17, installed: 2024.8.30]
# │   ├── charset-normalizer [required: >=2,<4, installed: 3.3.2]
# │   ├── idna [required: >=2.5,<4, installed: 3.10]
# │   └── urllib3 [required: >=1.21.1,<3, installed: 2.0.7]
# └── requests-oauthlib [required: >=1.2.0,<2, installed: 1.3.1]
#     ├── oauthlib [required: >=3.0.0, installed: 3.2.2]
#     └── requests [required: >=2.0.0, installed: 2.32.3]
#         ├── certifi [required: >=2017.4.17, installed: 2024.8.30]
#         ├── charset-normalizer [required: >=2,<4, installed: 3.3.2]
#         ├── idna [required: >=2.5,<4, installed: 3.10]
#         └── urllib3 [required: >=1.21.1,<3, installed: 2.0.7]
# vega-datasets==0.9.0
# └── pandas [required: Any, installed: 2.1.4]
#     ├── numpy [required: >=1.22.4,<2, installed: 1.26.4]
#     ├── python-dateutil [required: >=2.8.2, installed: 2.8.2]
#     │   └── six [required: >=1.5, installed: 1.16.0]
#     ├── pytz [required: >=2020.1, installed: 2024.2]
#     └── tzdata [required: >=2022.1, installed: 2024.1]
# wadllib==1.3.6
# wordcloud==1.9.3
# ├── matplotlib [required: Any, installed: 3.10.0.dev737+g0988fdaeca]
# │   ├── contourpy [required: >=1.0.1, installed: 1.3.0]
# │   │   └── numpy [required: >=1.23, installed: 1.26.4]
# │   ├── cycler [required: >=0.10, installed: 0.12.1]
# │   ├── fonttools [required: >=4.22.0, installed: 4.53.1]
# │   ├── kiwisolver [required: >=1.3.1, installed: 1.4.7]
# │   ├── numpy [required: >=1.23, installed: 1.26.4]
# │   ├── packaging [required: >=20.0, installed: 24.1]
# │   ├── pillow [required: >=8, installed: 10.4.0]
# │   ├── pyparsing [required: >=2.3.1, installed: 3.1.4]
# │   └── python-dateutil [required: >=2.7, installed: 2.8.2]
# │       └── six [required: >=1.5, installed: 1.16.0]
# ├── numpy [required: >=1.6.1, installed: 1.26.4]
# └── pillow [required: Any, installed: 10.4.0]
# xgboost==2.1.1
# ├── numpy [required: Any, installed: 1.26.4]
# ├── nvidia-nccl-cu12 [required: Any, installed: 2.23.4]
# └── scipy [required: Any, installed: 1.13.1]
#     └── numpy [required: >=1.22.4,<2.3, installed: 1.26.4]
# xlrd==2.0.1
# yellowbrick==1.5
# ├── cycler [required: >=0.10.0, installed: 0.12.1]
# ├── matplotlib [required: >=2.0.2,!=3.0.0, installed: 3.10.0.dev737+g0988fdaeca]
# │   ├── contourpy [required: >=1.0.1, installed: 1.3.0]
# │   │   └── numpy [required: >=1.23, installed: 1.26.4]
# │   ├── cycler [required: >=0.10, installed: 0.12.1]
# │   ├── fonttools [required: >=4.22.0, installed: 4.53.1]
# │   ├── kiwisolver [required: >=1.3.1, installed: 1.4.7]
# │   ├── numpy [required: >=1.23, installed: 1.26.4]
# │   ├── packaging [required: >=20.0, installed: 24.1]
# │   ├── pillow [required: >=8, installed: 10.4.0]
# │   ├── pyparsing [required: >=2.3.1, installed: 3.1.4]
# │   └── python-dateutil [required: >=2.7, installed: 2.8.2]
# │       └── six [required: >=1.5, installed: 1.16.0]
# ├── numpy [required: >=1.16.0, installed: 1.26.4]
# ├── scikit-learn [required: >=1.0.0, installed: 1.3.2]
# │   ├── joblib [required: >=1.1.1, installed: 1.4.2]
# │   ├── numpy [required: >=1.17.3,<2.0, installed: 1.26.4]
# │   ├── scipy [required: >=1.5.0, installed: 1.13.1]
# │   │   └── numpy [required: >=1.22.4,<2.3, installed: 1.26.4]
# │   └── threadpoolctl [required: >=2.0.0, installed: 3.5.0]
# └── scipy [required: >=1.0.0, installed: 1.13.1]
#     └── numpy [required: >=1.22.4,<2.3, installed: 1.26.4]
# yfinance==0.2.43
# ├── beautifulsoup4 [required: >=4.11.1, installed: 4.12.3]
# │   └── soupsieve [required: >1.2, installed: 2.6]
# ├── frozendict [required: >=2.3.4, installed: 2.4.4]
# ├── html5lib [required: >=1.1, installed: 1.1]
# │   ├── six [required: >=1.9, installed: 1.16.0]
# │   └── webencodings [required: Any, installed: 0.5.1]
# ├── lxml [required: >=4.9.1, installed: 4.9.4]
# ├── multitasking [required: >=0.0.7, installed: 0.0.11]
# ├── numpy [required: >=1.16.5, installed: 1.26.4]
# ├── pandas [required: >=1.3.0, installed: 2.1.4]
# │   ├── numpy [required: >=1.22.4,<2, installed: 1.26.4]
# │   ├── python-dateutil [required: >=2.8.2, installed: 2.8.2]
# │   │   └── six [required: >=1.5, installed: 1.16.0]
# │   ├── pytz [required: >=2020.1, installed: 2024.2]
# │   └── tzdata [required: >=2022.1, installed: 2024.1]
# ├── peewee [required: >=3.16.2, installed: 3.17.6]
# ├── platformdirs [required: >=2.0.0, installed: 4.3.6]
# ├── pytz [required: >=2022.5, installed: 2024.2]
# └── requests [required: >=2.31, installed: 2.32.3]
#     ├── certifi [required: >=2017.4.17, installed: 2024.8.30]
#     ├── charset-normalizer [required: >=2,<4, installed: 3.3.2]
#     ├── idna [required: >=2.5,<4, installed: 3.10]
#     └── urllib3 [required: >=1.21.1,<3, installed: 2.0.7]
